# %% [markdown]
# # Clustering Crypto

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

import pandas as pd
from urllib.request import Request, urlopen
from pandas.io.json import json_normalize
import json

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
request_url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Submit request and format output
response_data = requests.get(request_url).json()

# %%
# Submit request and format output
request = Request(request_url)
response = urlopen(request)
url_data = response.read()
data_json = json.loads(url_data)
#data = response_data.read()

# %%
df = pd.DataFrame(data_json['Data'])
df.head()
# Out:
#                  42   300  365     404      433      611      808  888  \
# Algorithm    Scrypt   N/A  X11  Scrypt      N/A  SHA-256  SHA-256  N/A
# BlockNumber  147668     0  NaN  241499  8875714      NaN        0    0
# BlockReward       0     0  NaN       0        2      NaN        0    0
# BlockTime         0     0  NaN      60        0      NaN        0   88
# BuiltOn         N/A  7605  N/A     N/A     7605      N/A      N/A  N/A
#
#                 1337 2015  ...  BDLR ROOBEE       CRW    MONT   EOSDT  \
# Algorithm        X13  X11  ...   N/A    N/A  Multiple  Ethash     N/A
# BlockNumber  2259647  NaN  ...   NaN      0   2611748       0     NaN
# BlockReward        0  NaN  ...   NaN      0      3.75       0     NaN
# BlockTime         60  NaN  ...   NaN      0        60       0     NaN
# BuiltOn          N/A  N/A  ...  7605   7605       N/A    7605  166503
#
#                 ABBC   OST  DAOC  BCB      XDNA
# Algorithm        X13   N/A   N/A  N/A       HEX
# BlockNumber  1047062     0     0  NaN    685105
# BlockReward        0     0     0  NaN  0.236364
# BlockTime         60     0     0  NaN        60
# BuiltOn          N/A  7605  7605  N/A       N/A
#
# [5 rows x 4233 columns]

# %%
# Creating a DataFrame

# %% [markdown]
# ### Data Preprocessing

# %%
# Traspose the data
df1 = df.T
df1.head()
# Out:
#     Algorithm BlockNumber BlockReward BlockTime BuiltOn   CoinName  \
# 42     Scrypt      147668           0         0     N/A    42 Coin
# 300       N/A           0           0         0    7605  300 token
# 365       X11         NaN         NaN       NaN     N/A    365Coin
# 404    Scrypt      241499           0        60     N/A    404Coin
# 433       N/A     8875714           2         0    7605  433 Token
#
#     ContentCreatedOn         FullName FullyPremined      Id  ... ProofType  \
# 42        1427211129     42 Coin (42)             0    4321  ...   PoW/PoS
# 300       1517935016  300 token (300)             0  749869  ...       N/A
# 365       1480032918    365Coin (365)             0   33639  ...   PoW/PoS
# 404       1466100361    404Coin (404)             0   21227  ...   PoW/PoS
# 433       1541597321  433 Token (433)             0  926547  ...       N/A
#
#                            SmartContractAddress SortOrder Sponsored Symbol  \
# 42                                          N/A        34     False     42
# 300  0xaec98a708810414878c3bcdf46aad31ded4a4557      2212     False    300
# 365                                         N/A       916     False    365
# 404                                         N/A       602     False    404
# 433  0x738505a5f31bf72e0b70298bca81150eb1b7c751      3505     False    433
#
#                                               Taxonomy TotalCoinSupply  \
# 42   {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...              42
# 300  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...             300
# 365  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...      2300000000
# 404  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...       532000000
# 433  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...      1000000000
#
#     TotalCoinsFreeFloat TotalCoinsMined                  Url
# 42                  N/A              42   /coins/42/overview
# 300                 N/A             300  /coins/300/overview
# 365                 N/A             NaN  /coins/365/overview
# 404                 N/A               0  /coins/404/overview
# 433                 N/A     1.08429e+08  /coins/433/overview
#
# [5 rows x 25 columns]

# %%
list(df1.columns)
# Out:
# ['Algorithm',
#  'BlockNumber',
#  'BlockReward',
#  'BlockTime',
#  'BuiltOn',
#  'CoinName',
#  'ContentCreatedOn',
#  'FullName',
#  'FullyPremined',
#  'Id',
#  'ImageUrl',
#  'IsTrading',
#  'Name',
#  'NetHashesPerSecond',
#  'PreMinedValue',
#  'ProofType',
#  'SmartContractAddress',
#  'SortOrder',
#  'Sponsored',
#  'Symbol',
#  'Taxonomy',
#  'TotalCoinSupply',
#  'TotalCoinsFreeFloat',
#  'TotalCoinsMined',
#  'Url']

# %%
# Remove unnecessary columns
df_clean = df1.drop(columns=['BuiltOn',
                 'ContentCreatedOn',
                 'FullName',
                 'Id',
                 'ImageUrl',
                 'PreMinedValue',
                 'SmartContractAddress',
                 'SortOrder',
                 'Sponsored',
                 'TotalCoinsFreeFloat',
                 'Url'])

# %%
df_clean.head()
# Out:
#     Algorithm BlockNumber BlockReward BlockTime   CoinName FullyPremined  \
# 42     Scrypt      147668           0         0    42 Coin             0
# 300       N/A           0           0         0  300 token             0
# 365       X11         NaN         NaN       NaN    365Coin             0
# 404    Scrypt      241499           0        60    404Coin             0
# 433       N/A     8875714           2         0  433 Token             0
#
#     IsTrading Name NetHashesPerSecond ProofType Symbol  \
# 42       True   42                  0   PoW/PoS     42
# 300      True  300                  0       N/A    300
# 365      True  365                NaN   PoW/PoS    365
# 404      True  404                  0   PoW/PoS    404
# 433     False  433    177465540903876       N/A    433
#
#                                               Taxonomy TotalCoinSupply  \
# 42   {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...              42
# 300  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...             300
# 365  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...      2300000000
# 404  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...       532000000
# 433  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...      1000000000
#
#     TotalCoinsMined
# 42               42
# 300             300
# 365             NaN
# 404               0
# 433     1.08429e+08

# %%
# Keep only cryptocurrencies that are on trading
df_clean = df_clean.loc[df_clean['IsTrading'] == True]
df_clean.head()
# Out:
#     Algorithm BlockNumber BlockReward BlockTime   CoinName FullyPremined  \
# 42     Scrypt      147668           0         0    42 Coin             0
# 300       N/A           0           0         0  300 token             0
# 365       X11         NaN         NaN       NaN    365Coin             0
# 404    Scrypt      241499           0        60    404Coin             0
# 611   SHA-256         NaN         NaN       NaN  SixEleven             0
#
#     IsTrading Name NetHashesPerSecond ProofType Symbol  \
# 42       True   42                  0   PoW/PoS     42
# 300      True  300                  0       N/A    300
# 365      True  365                NaN   PoW/PoS    365
# 404      True  404                  0   PoW/PoS    404
# 611      True  611                NaN       PoW    611
#
#                                               Taxonomy TotalCoinSupply  \
# 42   {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...              42
# 300  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...             300
# 365  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...      2300000000
# 404  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...       532000000
# 611  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...          611000
#
#     TotalCoinsMined
# 42               42
# 300             300
# 365             NaN
# 404               0
# 611             NaN

# %%
# Keep only cryptocurrencies with a working algorithm
df_clean = df_clean.loc[df_clean['Algorithm']!= 'N/A']
df_clean.head()
# Out:
#     Algorithm BlockNumber BlockReward BlockTime   CoinName FullyPremined  \
# 42     Scrypt      147668           0         0    42 Coin             0
# 365       X11         NaN         NaN       NaN    365Coin             0
# 404    Scrypt      241499           0        60    404Coin             0
# 611   SHA-256         NaN         NaN       NaN  SixEleven             0
# 808   SHA-256           0           0         0        808             0
#
#     IsTrading Name NetHashesPerSecond ProofType Symbol  \
# 42       True   42                  0   PoW/PoS     42
# 365      True  365                NaN   PoW/PoS    365
# 404      True  404                  0   PoW/PoS    404
# 611      True  611                NaN       PoW    611
# 808      True  808                  0   PoW/PoS    808
#
#                                               Taxonomy TotalCoinSupply  \
# 42   {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...              42
# 365  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...      2300000000
# 404  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...       532000000
# 611  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...          611000
# 808  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...               0
#
#     TotalCoinsMined
# 42               42
# 365             NaN
# 404               0
# 611             NaN
# 808               0

# %%
# Remove the "IsTrading" column
df_clean = df_clean.drop(columns = 'IsTrading')

# %%
# Removing rows with at least 1 null value
df_clean = df_clean.dropna()

# %%
# Removing rows with cryptocurrencies without coins mined
df_clean = df_clean.loc[df_clean['TotalCoinsMined'] != 0]

# %%
# Dropping rows where there are 'N/A' text values

# %%
# Fetching the cryptocurrencies names prior to drop them from crypto_df

# %%
# Removig the cryptocurrency name since it's not going to be used on the clustering algorithm

# %%
# Creating dummies variables for text features

# %%
# Standardizing data

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Using PCA to reduce dimension to 3 principal components

# %%
# Creating a DataFrame with the principal components data

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Finding the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range ok k values
for i in k:


# Create the Elbow Curve using hvPlot

# %% [markdown]
# Running K-Means with `k=<you best value for k here>`

# %%
# Initialize the K-Means model

# Fit the model

# Predict clusters

# Creating a new DataFrame including predicted clusters and cryptocurrencies features

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Creating a 3D-Scatter with the PCA data and the clusters

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scaling data to create the scatter plot

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
